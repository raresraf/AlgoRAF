# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn import preprocessing
import sklearn.metrics as metrics
import math
from scipy.stats import norm, skew
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
label_name = "math"
embedding_type = "perf" # time or perf

train = pd.get_dummies(pd.read_csv(f'../../dataset/{embedding_type}/small_{label_name}_dataset.csv'))

# %%
corr = train.corr()
highest_corr_features = corr.index[abs(corr["label"])>0.21]
plt.figure(figsize=(15,15))
g = sns.heatmap(train[highest_corr_features].corr(),annot=True)

# %%
print(train[highest_corr_features].columns)
# Out:
# Index(['branch-misses_INTERCEPT', 'page-faults_INTERCEPT', 'label',
#        'branch-misses_FEATURE_TYPE_LOGLOG_POLYNOMIAL',
#        'branches_FEATURE_TYPE_POLYNOMIAL',
#        'instructions_FEATURE_TYPE_POLYNOMIAL',
#        'stalled-cycles-frontend_FEATURE_TYPE_FRACTIONAL_POWER'],
#       dtype='object')
